# %% [markdown]
# # Steps

# %% [raw]
# 1. import the necessary libraries
# 2. import the dataset
# 3. Handling null values
# 4. Seperate Dependent and independent values
# 5. Encoding
# 6. Splitting traning and testing set
# 7. Feature scalling

# %% [markdown]
# # 1. Import Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Import Datasets

# %%
# Data it can be .csv, ,.tsv, .excel and json

# %%
dataset = pd.read_csv(r"Churn_Modelling.csv")
# dataset = pd.read_csv(r"C:\Users\Lenovo\OneDrive\Desktop\Python_1.0\12. Day - Data Pre-Processing\Churn_Modelling.csv")

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
dataset.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
dataset.shape
# Out:
# (10000, 14)

# %%
# discribe the information of the dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
dataset.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
dataset.Exited.value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
dataset.Gender.value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
sns.boxplot(dataset.Age)
plt.show()

# %% [markdown]
# # 3. Handling null values

# %% [raw]
# 1. Delete Null Values
# 2. Delete row/columns
# 3. Replace with mean median or mode

# %%
dataset.isnull().any()
# dataset.isnull()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # 4. Seperate Dependent and independent values

# %%
# dataset iloc[row, columns]
x = dataset.iloc[:, 3:13]

# %%
x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
y = dataset.iloc[:, 3:14]

# %%
y
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
# previoualy shape of the dataset
dataset.shape
# Out:
# (10000, 14)

# %%
# After grap the row and columns
x.shape
# Out:
# (10000, 10)

# %%
y.shape
# Out:
# (10000, 11)

# %% [markdown]
# # 5. Encoding

# %% [raw]
# 1. nominal=== not warried about orrangement of data
#
# Gender  Male  Female
#
# # Forther classified the 3 types
#
# A. one hot encoding
# B. one hot encoding it many categorical variable
# C. Mean Encoding
#
# 2. ordinal
#
# A. Label Encoding
# B. Target guided ordinal encoding

# %% [markdown]
# ### Label Encoding of gender column

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
x["Gender"] = le.fit_transform(x["Gender"])

# %%
x["Gender"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    1
# 9996    1
# 9997    0
# 9998    1
# 9999    0
# Name: Gender, Length: 10000, dtype: int32

# %%
x["Gender"].value_counts()
# Out:
# Gender
# 1    5457
# 0    4543
# Name: count, dtype: int64

# %%
x["Gender"].nunique()
# Out:
# 2

# %%
x.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France       0   42       2       0.00              1
# 1          608     Spain       0   41       1   83807.86              1
# 2          502    France       0   42       8  159660.80              3
# 3          699    France       0   39       1       0.00              2
# 4          850     Spain       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
x.Geography.value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %% [markdown]
# # One hot encoding of Geography column

# %%
geography = pd.get_dummies(x["Geography"],drop_first = True)

# %%
geography
# Out:
#       Germany  Spain
# 0       False  False
# 1       False   True
# 2       False  False
# 3       False  False
# 4       False   True
# ...       ...    ...
# 9995    False  False
# 9996    False  False
# 9997    False  False
# 9998     True  False
# 9999    False  False
#
# [10000 rows x 2 columns]

# %%
# concat
x = pd.concat([x, geography], axis = 1)

# %%
x.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France       0   42       2       0.00              1
# 1          608     Spain       0   41       1   83807.86              1
# 2          502    France       0   42       8  159660.80              3
# 3          699    France       0   39       1       0.00              2
# 4          850     Spain       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Germany  Spain
# 0          1               1        101348.88    False  False
# 1          0               1        112542.58    False   True
# 2          1               0        113931.57    False  False
# 3          0               0         93826.63    False  False
# 4          1               1         79084.10    False   True

# %%
# Drop the geography columns
x.drop(["Geography"], axis = 1, inplace=True)

# %%
x.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619       0   42       2       0.00              1          1
# 1          608       0   41       1   83807.86              1          0
# 2          502       0   42       8  159660.80              3          1
# 3          699       0   39       1       0.00              2          0
# 4          850       0   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain
# 0               1        101348.88    False  False
# 1               1        112542.58    False   True
# 2               0        113931.57    False  False
# 3               0         93826.63    False  False
# 4               1         79084.10    False   True

# %%
x.shape
# Out:
# (10000, 11)

# %% [markdown]
# # 6. Splitting into traning and testing set

# %% [raw]
# 100 Row
# tain data 70 - 80
# test data 20 - 30
#
# Performance new value

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

# %%
x_train.shape, x_test.shape,y_train.shape, y_test.shape
# Out:
# ((7000, 11), (3000, 11), (7000, 11), (3000, 11))

# %%
a = [1, 2, 3, 4, 5, 6]
b = [1, 0, 1, 5, 6, 3]

for i in range(5):
    a_train, a_test, b_train, b_test = train_test_split(a, b, test_size = 0.3, random_state = 0)
    print("With random state",a_train)
# Out:
# With random state [2, 4, 1, 5]
# With random state [2, 4, 1, 5]
# With random state [2, 4, 1, 5]
# With random state [2, 4, 1, 5]
# With random state [2, 4, 1, 5]

# %%
a = [1, 2, 3, 4, 5, 6]  # 4 value for training and 2 values for testing
b = [1, 0, 1, 5, 6, 3]

for i in range(5):
    a_train, a_test, b_train, b_test = train_test_split(a, b, test_size = 0.3)
    print("Without random state",a_train)
# Out:
# Without random state [6, 3, 5, 1]
# Without random state [6, 5, 4, 1]
# Without random state [1, 2, 5, 4]
# Without random state [3, 2, 4, 5]
# Without random state [3, 2, 6, 4]

# %% [markdown]
# # 7. Feature scalling

# %% [raw]
# Standard scaling mean = 0 and sd = 1
# min max scaling 0 and 1

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-0.09792126,  0.92295821, -0.55759842, ..., -0.76862426,
#         -0.56987189, -0.5731713 ],
#        [-1.12612023,  0.92295821,  0.01725942, ..., -1.39359887,
#         -0.56987189, -0.5731713 ],
#        [-0.62230274, -1.08347268,  3.5622161 , ..., -1.49739308,
#         -0.56987189, -0.5731713 ],
#        ...,
#        [ 0.89943174,  0.92295821, -0.36597914, ...,  1.41400417,
#         -0.56987189, -0.5731713 ],
#        [-0.62230274, -1.08347268, -0.07855022, ...,  0.84625811,
#         -0.56987189,  1.74467913],
#        [-0.28299708, -1.08347268,  0.87954618, ...,  0.32689267,
#          1.75478035, -0.5731713 ]])

# %%
y_test
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 9394          597   Germany  Female   35       8  131101.04              1
# 898           523    France  Female   40       2  102967.41              1
# 2398          706     Spain  Female   42       8   95386.82              1
# 5906          788    France    Male   32       4  112079.58              1
# 2343          706   Germany    Male   38       5  163034.82              2
# ...           ...       ...     ...  ...     ...        ...            ...
# 4004          530     Spain  Female   41       4       0.00              2
# 7375          639    France    Male   77       6   80926.02              2
# 9307          685    France    Male   40       2  168001.34              2
# 8394          692    France    Male   69      10  154953.94              1
# 5233          731   Germany  Female   49       4   88826.07              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...
