# %% [markdown]
# # Matplotlib Labels and Title

# %% [markdown]
# # import libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
#    Create Labels for a Plot:

# %% [markdown]
# - With Pyplot, can use the xlabel() and ylabel() functions to set a label for the x- and y-axis.

# %%
import matplotlib.pyplot as plt

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.xlabel("Avrage pluse")
plt.ylabel("Calories Burnage")

plt.show()

# %% [markdown]
#    Create a Title for a Plot:

# %% [markdown]
# - With Pyplot, we can use the title() function to set a title for the plot

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y, color = 'r')

plt.title("Sports Watch Data")
plt.xlabel("Over")
plt.ylabel("Average Run")

plt.show()

# %% [markdown]
# Set Font Properties for Title and Labels:

# %% [markdown]
# - We can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
font3 = {'family':'serif','color':'green','size':15}

plt.plot(x, y)

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Over", fontdict = font2)
plt.ylabel("Average Run", fontdict = font3)

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}


plt.plot(x, y, color = 'y')

plt.title("Sports Watch Data", fontdict = font1, color = 'r')
plt.xlabel("Over", fontdict = font2, color = 'b')
plt.ylabel("Average Run", fontdict = font3, color = 'b')

plt.show()

# %% [markdown]
# Position the Title:

# %% [markdown]
# - We can use the loc parameter in title() to position the title.

# %% [markdown]
# - Legal values are: 'left', 'right', and 'center'. Default value is 'center'.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}


plt.plot(x, y, color = 'y')

plt.title("Sports Watch Data", fontdict = font1, loc = 'right')
plt.xlabel("Over", fontdict = font2, color = 'r')
plt.ylabel("Average Run", fontdict = font3, color = 'r')

plt.show()

# %% [markdown]
# # Matplotlib Adding Grid Lines

# %% [markdown]
# Add Grid Lines to a Plot:

# %% [markdown]
# - With Pyplot, we can use the grid() function to add grid lines to the plot.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}


plt.plot(x, y)

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Over", fontdict = font2)
plt.ylabel("Average Run", fontdict = font2)

plt.grid()

plt.show()

# %% [markdown]
# Specify Which Grid Lines to Display:

# %% [markdown]
# - You can use the axis parameter in the grid() function to specify which grid lines to display.

# %% [markdown]
# - Legal values are: 'x', 'y', and 'both'. Default value is 'both'.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}


plt.plot(x, y)

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Over", fontdict = font2)
plt.ylabel("Average Run", fontdict = font2)

plt.grid(axis = 'x')

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}


plt.plot(x, y)

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Over", fontdict = font2)
plt.ylabel("Average Run", fontdict = font2)

plt.grid(color = 'g', linestyle = 'dotted', linewidth = 1.25)

plt.show()

# %% [markdown]
# # Matplotlib Bars

# %% [markdown]
# - The bar() function takes arguments that describes the layout of the bars.
#
# - The categories and their values represented by the first and second argument as arrays.

# %%
x = ["Apple", "Banana", "Orange"]
y = [400, 300, 500]

plt.bar(x, y)
plt.show()

# %% [markdown]
# Horizontal Bars:

# %% [markdown]
# - If want the bars to be displayed horizontally instead of vertically, use the barh() function.

# %%
x = np.array(["Apple", "Banana", "Orange", "Pineapple"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %% [markdown]
# Bar Color:

# %% [markdown]
# - The bar() and barh() take the keyword argument color to set the color of the bars.

# %%
x = np.array(["Apple", "Banana", "Orange", "Pineapple"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = 'r')
plt.show()

# %% [markdown]
# Bar Width:

# %% [markdown]
# - The bar() takes the keyword argument width to set the width of the bars.
#
# - The default width value is 0.8.
#
# - Note: For horizontal bars, use height instead of width.

# %%
x = np.array(["Apple", "Banana", "Orange", "Pineapple"])
y = np.array([3, 8, 5, 10])

plt.bar(x, y, width = 0.1)

plt.show()

# %% [markdown]
# Bar Height:

# %%
x = ['Banana', 'Orange', 'Apple', 'PineApple']
y = [3, 5, 8, 2]

plt.barh(x, y, height = 0.1, color = 'y')

plt.show()
