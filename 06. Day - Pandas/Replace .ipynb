# %% [markdown]
# # Replace

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Lenovo\OneDrive\Desktop\Python\Pandas\Health_systems.csv")

# %%
data
# Out:
#     Country_Region  Province_State        World_Bank_Name  \
# 0      Afghanistan             NaN            Afghanistan
# 1          Albania             NaN                Albania
# 2          Algeria             NaN                Algeria
# 3          Andorra             NaN                Andorra
# 4           Angola             NaN                 Angola
# ..             ...             ...                    ...
# 205             US  Virgin Islands  Virgin Islands (U.S.)
# 206            NaN             NaN     West Bank and Gaza
# 207            NaN             NaN            Yemen, Rep.
# 208         Zambia             NaN                 Zambia
# 209       Zimbabwe             NaN               Zimbabwe
#
#      Health_exp_pct_GDP_2016  Health_exp_public_pct_2016  \
# 0                       10.2                         5.1
# 1                        6.7                        41.4
# 2                        6.6                        67.7
# ...

# %%
data.replace(to_replace = 44.1 , value = 22)
# Out:
#     Country_Region  Province_State        World_Bank_Name  \
# 0      Afghanistan             NaN            Afghanistan
# 1          Albania             NaN                Albania
# 2          Algeria             NaN                Algeria
# 3          Andorra             NaN                Andorra
# 4           Angola             NaN                 Angola
# ..             ...             ...                    ...
# 205             US  Virgin Islands  Virgin Islands (U.S.)
# 206            NaN             NaN     West Bank and Gaza
# 207            NaN             NaN            Yemen, Rep.
# 208         Zambia             NaN                 Zambia
# 209       Zimbabwe             NaN               Zimbabwe
#
#      Health_exp_pct_GDP_2016  Health_exp_public_pct_2016  \
# 0                       10.2                         5.1
# 1                        6.7                        41.4
# 2                        6.6                        67.7
# ...

# %%
data.replace(to_replace = "Albania", value = "Python")
# Out:
#     Country_Region  Province_State        World_Bank_Name  \
# 0      Afghanistan             NaN            Afghanistan
# 1           Python             NaN                 Python
# 2          Algeria             NaN                Algeria
# 3          Andorra             NaN                Andorra
# 4           Angola             NaN                 Angola
# ..             ...             ...                    ...
# 205             US  Virgin Islands  Virgin Islands (U.S.)
# 206            NaN             NaN     West Bank and Gaza
# 207            NaN             NaN            Yemen, Rep.
# 208         Zambia             NaN                 Zambia
# 209       Zimbabwe             NaN               Zimbabwe
#
#      Health_exp_pct_GDP_2016  Health_exp_public_pct_2016  \
# 0                       10.2                         5.1
# 1                        6.7                        41.4
# 2                        6.6                        67.7
# ...
